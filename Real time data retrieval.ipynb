# %%
#Import relevant libraries
import pysurveycto
import pandas as pd
import time
import datetime

# %%
#connect to the surveyCTO API
scto = pysurveycto.SurveyCTOObject('ghananatlsurvey','tr1328@nyu.edu', 'Ping10gratis!')

# %%
#specify date
date_input = datetime.datetime(2021,8,10)
#retrive the form data in a json format
data = scto.get_form_data('negotiation_data_survey', format='json', oldest_completion_date = date_input)

#Convert the json folder to a pandas dataframe
#df = pd.json_normalize(data)

# %%
data
# Out:
# [{'CompletionDate': 'Aug 10, 2021 11:09:35 AM',
#   'SubmissionDate': 'Aug 10, 2021 11:09:35 AM',
#   'starttime': 'Aug 10, 2021 10:56:46 AM',
#   'endtime': 'Aug 10, 2021 11:09:33 AM',
#   'username': 'kdn3432@nyu.edu',
#   'Trader_Id': '888',
#   'Trader_Name': 'Aliatu Dada',
#   'trader_other': 'Tft_1',
#   'Farmer_Id': 'F_00119',
#   'Farmer_Name': 'Thomas Owusu',
#   'offer_quantity': '30',
#   'crop': '8',
#   'farmer_asking_price_plantain_1': '40/35/20',
#   'offer_price_plantain_1': '30/20/15',
#   'farmer_asking_price_plantain_2': '30/20/15',
#   'offer_price_plantain_2': '30/20/15',
#   'agreement_reached': '1',
#   'payment_plan': '1',
#   'farm_visitdate': 'Oct 1, 2021',
#   'comment': 'Farmer agreed to reduce the price because the trader was not happy about where the farm is located. They agreed to meet on 1 September, the agreed price is 30/20/15',
#   'instanceID': 'uuid:2e48f60c-ebed-45da-80eb-346d1bd084cb',
#   'formdef_version': '2108101404',
# ...
